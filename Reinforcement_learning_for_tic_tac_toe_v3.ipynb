# %% [markdown]
# <a href="https://colab.research.google.com/github/RussAbbott/TicTacToe/blob/master/Reinforcement_learning_for_tic_tac_toe_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reinforcement learning for tic-tac-toe
#
# In which we solve the problem of teaching a neural network to play tic-tac-toe.
#
# Based on Daniel Sauble's [article](https://medium.com/swlh/tic-tac-toe-and-deep-neural-networks-ea600bc53f51) and Github [repo](https://github.com/djsauble/tic-tac-toe-ai/blob/master/reinforcement_learning_for_tic-tac-toe.ipynb).

# %%
#@title Imports
import random
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.backend import reshape
from keras.utils.np_utils import to_categorical

# %%
#@title Basic classes and functions

# ==============================================================================
# Two simple classes.

class Config:
    '''
    The static information about the game
    '''
    def __init__(self, board_side=3):
        self.board_side = board_side
        self.triples = collect_the_triples(board_side)
        self.x = 1
        self.o = -1
        self.blank = 0
        self.draw = 0
        self.player_symbol = {self.o: ' O ', self.draw: '   ', self.x: ' X ', }
        # For minimax
        self.depth = 5

class Obs:
    '''
    Obs is for Observation. The dynamic information about the game.
    '''
    def __init__(self, config):
        self.board = new_board(config.board_side, config.blank)
        self.history = []
        self.player_to_move = config.x


# ==============================================================================


def child_board(board, r, c, player):
    next_board = board.copy()
    next_board[r][c] = player
    return next_board


def collect_the_triples(board_side):
    '''
    Generate all 3-in-a-row cell sequences
    Each cell sequence will be returned as [(r, c), (r, c), (r, c)],
    where the (r, c)'s are the cell coordinates. (Each cell will appear in a number of sequences.)
    '''
    row_triples = [[(r, c) for c in range(board_side)] for r in range(board_side)]
    col_triples = [[(r, c)  for r in range(board_side)] for c in range(board_side)]
    pos_diag = [(rc, rc) for rc in range(board_side)]                  # [(0, 0), (1, 1), (2, 2)]]
    neg_diag = [(r, (board_side - 1) - r) for r in range(board_side)]  # [(0, 2), (1, 1), (2, 0)]]
                    
    all_triples = row_triples + col_triples + [pos_diag, neg_diag]
    return all_triples


def game_status(board, config, requested_counts={3: 0, 2: 0, 1: 0}):
    '''
    returns: game_over, counts

    The counts are dictionary items() of numbers of triples with exactly 1, 2, or 3 of a kind with the rest blanks.
    The o's counts are counted negatively to facilitate minimax.
    '''
    triples = config.triples
    counts = requested_counts.copy()
    any_triples_in_play = False
    x = config.x
    o = config.o

    for triple in triples:
        triple_with_values = [board[r][c] for (r, c) in triple]
        xs_in_triple, os_in_triple = triple_with_values.count(x), triple_with_values.count(o)

        # A triple is in play if it has no more than one player and that player has not won the triple
        
        # The following is about the |= (in-place 'or') operation.
        # |= does not short-circuit even if the LHS is already true. That is,
        #                   x |= expression
        # will evaluate expression even if x is already true. Hence:
        if not any_triples_in_play:
            any_triples_in_play = ( (xs_in_triple == 0 or os_in_triple == 0) and
                                    (xs_in_triple + os_in_triple < 3)
                                  )

        for count in requested_counts:
            if xs_in_triple == count and os_in_triple == 0: 
                counts[count] += 1

            # Count the opponents scores negatively
            if os_in_triple == count and xs_in_triple == 0: 
                counts[count] -= 1

    game_over = counts[3] != 0 or not any_triples_in_play

    return game_over, list(counts.items())


def get_winner(counts, config):
    winner = config.x if counts[3] > 0 else config.o if counts[3] < 0 else config.draw
    return winner
               
               
def moves_to_board(moves, config, verbose=False):
    '''
    Reconstruct the board from a list of moves
    '''
    board = new_board(config.board_side, config.blank)
    for player, (row, col) in moves:
        board[row, col] = player
        if verbose:
            print_board(board, config)
            print('\n')
    return board


def new_board(board_side, blank):
    board = np.full( (board_side, board_side), blank, dtype='int')
    return board


def new_game():

    config  = Config()
    obs = Obs(config)
    return obs, config


def other_player(player):
    return player * (-1)


def print_board(board, config, title=''):
    '''
    Print the current board
    '''
    player_symbol = config.player_symbol
    rows = 'ABC'
    print(f'\n{title}')
    print('    1   2   3')
    for r in range(len(board)):
        print(f' {rows[r]} ', end='')
        for c in range(len(board[r])):
            mark = player_symbol[board[r][c]]
            last_in_row = c == len(board[r]) - 1
            print(f'{mark}{"" if last_in_row else "|"}', end='\n' if last_in_row else '')
        if (r < len(board) - 1):
            print("   -----------")

    game_over, counts = game_status(board, config)
    winner = get_winner(dict(counts), config)
    if game_over:
        mark = player_symbol[winner]
        caption = '    ' + mark + " wins" if winner in [config.x, config.o] else "      Draw" 
        dots = "   ..........."
        print(dots)
        print(caption)
        print(dots)

def unzip(zipped):
    [a, b] = zip(*zipped)
    return list(a), list(b)
    

def valid_moves(board):
    '''
    Get a list of valid moves
    '''
    board_side = len(board)
    moves = [(r, c) for r in range(board_side) for c in range(board_side) if board[r][c] == 0]
    return moves

# %%
# @title Test the basic methods

_obs, config = new_game()
config = Config()

b = 0
x = 1
o = -1

history = [(x, (0, 0)), (x, (1, 1)), (x, (2, 2)), # X wins
           (o, (2, 2)), (o, (1, 2)), (o, (0, 2)), # O wins
           (x, (1, 2)), (o, (1, 0)), (x, (2, 1)), (o, (0, 1)), # Draw
           ]

# Make it an assignment statement so that no value is displayed at the end.
_ = moves_to_board(history, config, verbose=True)

# %%
# @title A game simulator and move strategies

def explain_move_input():
    print(f'Indicate a move as follows.\n')
    print('   1     2    3')
    # print()
    print('A  A1 |  A2 | A3')
    print('  ---------------')
    print('B  B2 |  B2 | B3')
    print('  ---------------')
    print('C  C3 |  C2 | C3')
    print('   Lower case a, b, c are also ok.\n')


def get_input(board, mark, blank):
    c_to_n = {'A': 0, 'B': 1, 'C': 2, 'a': 0, 'b': 1, 'c': 2, '1': 0, '2': 1, '3': 2}
    valid_input = False
    while not valid_input:
        strng = input(f'\n{mark[1]}\'s move > ')
        digits = [c_to_n[c] for c in strng if c in c_to_n]

        if len(digits) != 2:
            print('Invalid input')
            continue

        [r, c] = digits 
        cell = board[r][c]
        if cell == blank:
            return r, c
        else:
            print(f'Cell {strng} already contains {config.player_symbol[cell]}\n')
            

def human_player(board, player, config):
    print()
    print_board(board, config)
    r, c = get_input(board, config.player_symbol[player], config.blank)
    return r, c


def minimax_moves_and_score(depth, board, player, config, verbose=False):
    v_moves = valid_moves(board)
    move_scores = [((r, c), minimax_score(depth-1, child_board(board, r, c, player), other_player(player), config))
                   for r, c in v_moves]
    is_maximizer = player == config.x
    min_or_max = max if is_maximizer else min
    best_move_score = min_or_max(move_scores, key=lambda m_s: m_s[1])
    best_score = best_move_score[1] 
    best_moves = [move for move, score in move_scores if score == best_score]

    # print(f'<== {depth=} {config.depth=}')
    if verbose and depth == config.depth:
        # print(f"\n\nplayer = {config.player_symbol[player][1]}.")
        print_board(board, config, title=f"\n\nplayer = {config.player_symbol[player][1]}.")
        print()
        for move, score in move_scores:
            print(f"{move} -> {score} {' (ok)' if score == best_score else ''}")
        print(f"{best_moves = }")

    return best_moves, best_score


def minimax_player(board, player, config, verbose=False):
    if np.count_nonzero(board==0) == 9:
         return random.choice([(0, 0), (0, 2), (2, 0), (2, 2)])       
    moves, _score = minimax_moves_and_score(config.depth, board, player, config, verbose=verbose)
    move = random.choice(moves)
    return move


def minimax_score(depth, board, player, config):
    game_over, score = game_status(board, config)
    if depth == 0 or game_over:
       return score
    
    _moves, score = minimax_moves_and_score(depth, board, player, config)
    return score


def model_player(board, player, model, config, verbose=False, rnd=0):
    '''
    Use the model to get the best next move for the given player at the given board position
    '''
    scores = []
    v_moves = valid_moves(board)
    # Make predictions for each possible move
    if verbose:
        print('\n>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
    for row, col in v_moves:
        # row, col = v_moves[i]
        next_board = np.array(board)
        next_board[row][col] = player
        next_board_1d = next_board.reshape((-1, 9))
        prediction = model.predict(next_board_1d, verbose=False)[0]

        if verbose:
            print_board(next_board, config, title=f'If {config.player_symbol[player]} moves to {(row, col)}')
            for label, prob in zip(["Draw", "X wins", "O wins"], prediction):
                print(label, '=', round(prob, 2))
                print(f'{label} = {round(prob, 2)}')

        if player == config.x:
            draw_prediction, win_prediction, loss_prediction = prediction
        elif player == config.o:
            draw_prediction, loss_prediction, win_prediction = prediction
        else:
            raise Exception(f'{player = } is neither {config.x = } nor {config.o = }.\n{player == config.x = }  {player == config.o = }')

        if win_prediction > loss_prediction:
            scores.append(win_prediction - loss_prediction)
        else:
            scores.append(draw_prediction - loss_prediction)

    # Choose the best move with a random factor
    best_moves_indices = np.flip(np.argsort(scores))
    move = None
    for i in range(len(best_moves_indices)):
        if random.random() * rnd < 0.5:
            move = v_moves[best_moves_indices[i]]

    if move == None:
        # Choose a move at random
        move = random.choice(v_moves)

    if verbose:
        print(f'\n==> {config.player_symbol[player]} moves to {move}.')
        print('<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<')

    return move


def random_player(board, _player, _config):
    '''
    Return a random (valid) move
    '''
    v_moves = valid_moves(board)
    move = random.choice(v_moves)
    return move


def select_a_move(board, player, move_strategy, config, verbose=False, rnd=0):
    '''
    player is either 1 for X or -1 for O
    '''
    if isinstance(move_strategy, Sequential):
        return model_player(board, player, move_strategy, config, verbose=verbose, rnd=rnd)

    if move_strategy in [minimax_player, win_block_player]:
        return minimax_player(board, player, config, verbose=verbose)

    if move_strategy == human_player:
        return human_player(board, player, config)

    return random_player(board, player, config)


def simulate_game(x_strategy=random_player, o_strategy=random_player, verbose=False, rnd=0):
    '''
    Simulate a game
    '''
    
    obs, config = new_game()

    move_history = []
    board_history = [obs.board.copy()]

    x = config.x
    o = config.o
    draw = config.draw

    if human_player in [x_strategy, o_strategy]:
        explain_move_input()

    # game_status returns (status, score), where status is True/False depending on whether the game is over. 
    # So, this says, repeat while status is not game_over.
    while not game_status(obs.board, config)[0]:

        # player_to_move will be either 1 or -1
        player_to_move = obs.player_to_move
        player_strategy = x_strategy if player_to_move == x else o_strategy   
        row, col = select_a_move(obs.board, player_to_move, player_strategy, config, verbose=verbose, rnd=rnd)
        # Make the move
        obs.board[row][col] = player_to_move

        # Add the move to history
        move_history.append((player_to_move, (row, col)))
        board_history.append(obs.board.copy())
        
        # Switch the active player
        obs.player_to_move = other_player(player_to_move)


    if human_player in [x_strategy, o_strategy]:
        print_board(obs.board, config, title='\n    Game over\n   ...........', )
        
    return move_history, board_history
    

def win_block_player(board, player, config, depth=1, verbose=False):
    '''
    The win_block_player is a minimax player limited to a search depth of 1.
    In other words, it looks ahead one move: what will its current move yield?
    
    This lets it determine whether it can win on its current move. 
    
    It also allows it to determine whether it is leaving the other player 
    2 in a row, which will let the other player win on its next move.
    '''
    config.depth = depth
    return minimax_player(board, player, config, verbose=verbose)

# %%
#@title Test the game simulator

random.seed()

x_strategy, o_strategy =  random_player, win_block_player

move_history, board_history = simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, verbose=False)

if human_player not in [x_strategy, o_strategy]:
    config = Config()
    for board in board_history:
        print_board(board, config)
# Out:
#     1   2   3
#  A    |   |
#    -----------
#  B    |   |
#    -----------
#  C    |   |
#
#
#     1   2   3
#  A    |   |
#    -----------
#  B    |   |
#    -----------
#  C    | X |
#
#
#     1   2   3
#  A    |   |
#    -----------
#  B    | O |
#    -----------
#  C    | X |
#
#
#     1   2   3
#  A  X |   |
#    -----------
#  B    | O |
#    -----------
#  C    | X |
#
#
#     1   2   3
#  A  X |   |
#    -----------
#  B    | O |
#    -----------
#  C  O | X |
#
#
#     1   2   3
#  A  X |   |
#    -----------
#  B    | O | X
#    -----------
#  C  O | X |
#
#
#     1   2   3
#  A  X |   | O
#    -----------
#  B    | O | X
#    -----------
#  C  O | X |
#    ...........
#      O  wins
#    ...........

# %%
# @title  Generate a collection of simulated games to calculate win/lose statistics for first and second players--and later to train our neural network. 
# 'X' (player 1) should have an edge due to first mover advantage.

def game_stats(x_strategy, o_strategy, nbr_games, games):
    '''
    Aggregate win/loss/draw stats for a player
    Input: a list of (move_history, board_history) pairs.
    We ignore the move_history and look only at the final board_history
    '''
    if isinstance(x_strategy, Sequential):
        x_strategy = model_player 

    if isinstance(o_strategy, Sequential):
        o_strategy = model_player 

    print(f'X ({x_strategy.__name__}) vs O ({o_strategy.__name__}). {nbr_games} games.')

    # Keep the stats from the perspective of the x player
    stats = {"x": 0, "o": 0, "draw": 0}
    for _move_history, board_history in games:
        _status, counts = game_status(board_history[-1], config)
        counts = dict(counts)
        if counts[3] > 0:
            stats["x"] += 1
        elif counts[3] < 0:
            stats["o"] += 1
        else:
            stats["draw"] += 1
    
    player_x_pct = stats["x"] / len(games) * 100
    player_o_pct = stats["o"] / len(games) * 100
    draw_pct = stats["draw"] / len(games) * 100

    print("Player\twins\tpct wins")
    print("------\t----\t--------")
    print(f"   x\t {stats['x']}\t  {round(player_x_pct)}%")
    print(f"   o\t {stats['o']}\t  {round(player_o_pct)}%")
    print(f" Draws\t {stats['draw']}\t  {round(draw_pct)}%")
    print()


x_strategy, o_strategy, nbr_games = random_player, random_player, 1000
games_rr = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(nbr_games)] 
game_stats(x_strategy, o_strategy, nbr_games, games_rr)

x_strategy, o_strategy, nbr_games = win_block_player, random_player, 100
games_wr = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(nbr_games)] 
game_stats(x_strategy, o_strategy, nbr_games, games_wr)

x_strategy, o_strategy, nbr_games = random_player, win_block_player, 100
games_rw = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(nbr_games)] 
game_stats(x_strategy, o_strategy, nbr_games, games_rw)

games = games_rr + games_wr*10 + games_rw*10
# Out:
# X (random_player) vs O (random_player). 1000 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 582	  58%
#    o	 286	  29%
#  Draws	 132	  13%
#
# X (win_block_player) vs O (random_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 100	  100%
#    o	 0	  0%
#  Draws	 0	  0%
#
# X (random_player) vs O (win_block_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 0	  0%
#    o	 86	  86%
#  Draws	 14	  14%

# %%
# @title Functions to normalize and label game states.

def tuple_board(board):
    '''
    Convert a 3x3 board into a 3-tuple of 3-tuples
    '''
    list_of_tuples = [tuple(row.tolist()) for row in board]
    return tuple(list_of_tuples)


def normalize_board_state(board, board_state_mapping, board_states_seen):
    '''
    Input: a 3x3 board state
    Output: the distinguished board state that represents the input board state
    First check to see if the input board state already has an associated
    distinguished board state. If so, return that distinguished board state.
    If not, generate all 8 equivalent board states. Select one of the, arbitrarily
    the smallest under < . Point all 8 board states to the distiguished board state.
    Do all this with tuples because dictionaries require immutable keys.
    '''
    t_board = tuple_board(board)
    # Include the tuple version of the board to board_states_seen
    board_states_seen.add(t_board)
    n_board = board_state_mapping.get(t_board)
    if n_board is not None:
        return n_board

    t_boards = []
    for _ in range(4):
        t_boards.append(t_board)
        t_boards.append(tuple_board(np.transpose(t_board)))
        t_board = tuple_board(np.rot90(t_board))
    min_board = min(t_boards)

    for t_board in t_boards:
        if t_board not in board_state_mapping:
            board_state_mapping[t_board] = min_board

    return min_board


def board_history_to_labelled_board_states(board_history, board_state_mapping, board_states_seen):
    '''
    Input: a list of board positions for a game.
    Output: a list of pairs, where each board position is paired with (labeled by) the winner of the game.
    In the code above, a win by o is indicated by -1; a draw is indicated by 0; a win by x is indicated by 1.
    However, we will use a neural net that maps board states to categories. Categories must be
    non-negative integers. So we map (-1, 0, 1) -> (2, 0, 1) for category designation. 
    '''
    # Get the winner of the board_history by looking at the final board in board_history.
    _status, counts_as_tuples = game_status(board_history[-1], config)
    winner = get_winner(dict(counts_as_tuples), config)
    
    # winner will be: -1: o won; 0: draw; 1: x won
    # convert the winner to 2: o won; 0: draw; 1: x won
    # In categorical learning, the categories must all be non-negative integers
    winner_to_category = {0: 0, 1: 1, -1: 2}
    winner_category = winner_to_category[winner]
    normalized_board_states = [normalize_board_state(board, board_state_mapping, board_states_seen) for board in board_history]

    # Make a list of the winner category as long as the board_history
    list_of_winner_category = [winner_category] * len(board_history)
    # Zip the two lists together and return the result.
    return zip(normalized_board_states, list_of_winner_category)


def labeled_and_shuffled_game_histories(games):
    '''
    Input: a list of (move_history, board_history) pairs, one for each game.

    Produce a collection of board states labelled by who eventually won that game.
    Return X y where X and y are lists of board states and the correspoding labels/categories.
    The variable names X and y are the names used traditionally. X is upper case.

    1. Ignore move_history. Work only with board_history
    2. Use the last element in board_history to determine the game winner.
    3. Pair each board position in board_history with that winner as a category/label.
    4. Append the list of board positions to X and a list of length len(board_history) of winner to y   
    5. Shuffle X and y simultaneously so that the labelled board posistions are spread around. 
    '''

    # Because of symmetry, for every board state there are 7 equivalent board states. 
    # Select one of the 8 to represent them all.
    # Store the mapping from board_state to distinguished board_state in the following cache (dictionary).
    # Also use the dictionary to store the count of distinct board states.
    board_state_mapping = {}
    board_states_seen = set()

    # Will be a list of (board_position, label) pair.
    shuffled_Xs_ys = []

    for _move_history, board_history in games:
        shuffled_Xs_ys_for_a_game = board_history_to_labelled_board_states(board_history, board_state_mapping, board_states_seen)
        shuffled_Xs_ys += shuffled_Xs_ys_for_a_game

    # Shuffle the (board_position, winner) pairs so that not all the winners/losers occur first.
    # random.shuffle shuffles a list in place
    random.shuffle(shuffled_Xs_ys)

    print(f'A simple upper bound for the size of the tic-tac-toe state space is {3**9 = }. ')
    print('(Three states for each cell and nine cells.) ')
    print('This count includes many illegal positions, such as a position with five Xs and no Os')
    print('or a position in which both players have a row of three.\n')
    print('A more careful count, removing these illegal positions, gives 5,478.')
    print('When rotations and reflections are considered, there are 765 different positions.')
    print('Wikipedia: https://en.wikipedia.org/w/index.php?title=Game_complexity&oldid=950763371#Example:_tic-tac-toe_(noughts_and_crosses)\n')

    print(f'Summary. Valid board states: 5478.  After considering symmetries: 765.\n')
    print(f'Board states seen: {len(board_states_seen)}. Number of distinguished boards: {len(set(board_state_mapping.values()))} ')

    return shuffled_Xs_ys

# %%
# @title Label the board postions in the games abd shuffkle the labelled pairs.

shuffled_Xs_ys = labeled_and_shuffled_game_histories(games)

X, y = unzip(shuffled_Xs_ys)

X = np.array(X).reshape((-1, 9))
y = to_categorical(y, num_classes=3)

# Split out the train and test data
trainNum = int(len(X) * 0.8)
X_train, X_test, y_train, y_test = X[:trainNum], X[trainNum:], y[:trainNum], y[trainNum:]
# Out:
# A simple upper bound for the size of the tic-tac-toe state space is 3**9 = 19683.
# (Three states for each cell and nine cells.)
# This count includes many illegal positions, such as a position with five Xs and no Os
# or a position in which both players have a row of three.
#
# A more careful count, removing these illegal positions, gives 5,478.
# When rotations and reflections are considered, there are 765 different positions.
# Wikipedia: https://en.wikipedia.org/w/index.php?title=Game_complexity&oldid=950763371#Example:_tic-tac-toe_(noughts_and_crosses)
#
# Summary. Valid board states: 5478.  After considering symmetries: 765.
#
# Board states seen: 3433. Number of distinguished boards: 759

# %% [markdown]
# * We choose a DNN architecture since we effectively want to predict the outcome of a game based on the given board state.
# * The input for each cell is the board state, which we reshape into a flat array of 9 elements, each element of which can be a 0 (empty cell), 1 (player 1 move), or 2 (player 2 move).
# * The output is the result of the game (win, loss, or draw). We use a one-hot encoded array for this.

# %%
#@title Prepare the neural net.

def build_model(board_side):
    '''
    Create a NN model
    '''
    num_cells = board_side * board_side
    outcomes = 3 # The number of possible outcomes in a game. (draw, X-wins, O-wins)
    model = Sequential([
                        Dense(200, input_shape=(num_cells, ), activation='relu'),
                        Dropout(0.2),
                        Dense(125, activation='relu'),
                        Dense(75, activation='relu'),
                        Dropout(0.1),
                        Dense(25, activation='relu'),
                        Dense(outcomes, activation='softmax'),
                        ])
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])
    print(model.summary())    

    return model

# %%
#@title Train the model on the tic-tac-toe games  generated earlier.

_obs, config = new_game()
model = build_model(config.board_side)


# Train the model
n_epochs = 500
batch_size = 100

# history output is not used
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=n_epochs, batch_size=batch_size)
print('\n\tThe model is trained\n')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               2000
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 125)               25125
#
#  dense_2 (Dense)             (None, 75)                9450
#
#  dropout_1 (Dropout)         (None, 75)                0
#
#  dense_3 (Dense)             (None, 25)                1900
#
#  dense_4 (Dense)             (None, 3)                 78
#
# =================================================================
# Total params: 38,553
# Trainable params: 38,553
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 191/191 [==============================] - 2s 7ms/step - loss: 0.6558 - acc: 0.7250 - val_loss: 0.5770 - val_acc: 0.7592
# Epoch 2/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5800 - acc: 0.7570 - val_loss: 0.5519 - val_acc: 0.7725
# Epoch 3/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5613 - acc: 0.7635 - val_loss: 0.5487 - val_acc: 0.7655
# Epoch 4/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5556 - acc: 0.7642 - val_loss: 0.5448 - val_acc: 0.7744
# Epoch 5/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5470 - acc: 0.7710 - val_loss: 0.5375 - val_acc: 0.7731
# Epoch 6/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5427 - acc: 0.7709 - val_loss: 0.5424 - val_acc: 0.7695
# Epoch 7/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5402 - acc: 0.7710 - val_loss: 0.5285 - val_acc: 0.7771
# Epoch 8/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5347 - acc: 0.7724 - val_loss: 0.5343 - val_acc: 0.7737
# Epoch 9/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5338 - acc: 0.7726 - val_loss: 0.5307 - val_acc: 0.7735
# Epoch 10/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5319 - acc: 0.7728 - val_loss: 0.5308 - val_acc: 0.7794
# Epoch 11/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5275 - acc: 0.7756 - val_loss: 0.5261 - val_acc: 0.7752
# Epoch 12/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5271 - acc: 0.7752 - val_loss: 0.5330 - val_acc: 0.7773
# Epoch 13/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5280 - acc: 0.7747 - val_loss: 0.5269 - val_acc: 0.7767
# Epoch 14/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5246 - acc: 0.7757 - val_loss: 0.5250 - val_acc: 0.7788
# Epoch 15/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5255 - acc: 0.7765 - val_loss: 0.5243 - val_acc: 0.7769
# Epoch 16/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5235 - acc: 0.7770 - val_loss: 0.5231 - val_acc: 0.7788
# Epoch 17/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5233 - acc: 0.7761 - val_loss: 0.5221 - val_acc: 0.7777
# Epoch 18/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5225 - acc: 0.7768 - val_loss: 0.5217 - val_acc: 0.7777
# Epoch 19/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5230 - acc: 0.7769 - val_loss: 0.5231 - val_acc: 0.7771
# Epoch 20/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5202 - acc: 0.7779 - val_loss: 0.5228 - val_acc: 0.7767
# Epoch 21/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5209 - acc: 0.7766 - val_loss: 0.5260 - val_acc: 0.7727
# Epoch 22/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5194 - acc: 0.7775 - val_loss: 0.5257 - val_acc: 0.7771
# Epoch 23/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7786 - val_loss: 0.5313 - val_acc: 0.7748
# Epoch 24/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5194 - acc: 0.7783 - val_loss: 0.5224 - val_acc: 0.7779
# Epoch 25/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5188 - acc: 0.7792 - val_loss: 0.5255 - val_acc: 0.7805
# Epoch 26/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5187 - acc: 0.7788 - val_loss: 0.5267 - val_acc: 0.7758
# Epoch 27/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5166 - acc: 0.7778 - val_loss: 0.5257 - val_acc: 0.7779
# Epoch 28/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5167 - acc: 0.7782 - val_loss: 0.5234 - val_acc: 0.7786
# Epoch 29/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5180 - acc: 0.7795 - val_loss: 0.5225 - val_acc: 0.7779
# Epoch 30/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5171 - acc: 0.7780 - val_loss: 0.5220 - val_acc: 0.7771
# Epoch 31/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5149 - acc: 0.7795 - val_loss: 0.5244 - val_acc: 0.7790
# Epoch 32/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5176 - acc: 0.7790 - val_loss: 0.5275 - val_acc: 0.7784
# Epoch 33/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7790 - val_loss: 0.5308 - val_acc: 0.7756
# Epoch 34/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5165 - acc: 0.7782 - val_loss: 0.5267 - val_acc: 0.7765
# Epoch 35/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5156 - acc: 0.7783 - val_loss: 0.5218 - val_acc: 0.7767
# Epoch 36/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7791 - val_loss: 0.5317 - val_acc: 0.7786
# Epoch 37/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5151 - acc: 0.7793 - val_loss: 0.5223 - val_acc: 0.7786
# Epoch 38/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7798 - val_loss: 0.5231 - val_acc: 0.7771
# Epoch 39/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5151 - acc: 0.7801 - val_loss: 0.5239 - val_acc: 0.7782
# Epoch 40/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5147 - acc: 0.7800 - val_loss: 0.5281 - val_acc: 0.7796
# Epoch 41/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5145 - acc: 0.7789 - val_loss: 0.5262 - val_acc: 0.7763
# Epoch 42/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5126 - acc: 0.7773 - val_loss: 0.5229 - val_acc: 0.7773
# Epoch 43/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5124 - acc: 0.7797 - val_loss: 0.5238 - val_acc: 0.7773
# Epoch 44/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5145 - acc: 0.7794 - val_loss: 0.5210 - val_acc: 0.7782
# Epoch 45/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5156 - acc: 0.7790 - val_loss: 0.5253 - val_acc: 0.7756
# Epoch 46/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5139 - acc: 0.7789 - val_loss: 0.5290 - val_acc: 0.7775
# Epoch 47/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5140 - acc: 0.7779 - val_loss: 0.5245 - val_acc: 0.7794
# Epoch 48/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5128 - acc: 0.7795 - val_loss: 0.5270 - val_acc: 0.7790
# Epoch 49/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5140 - acc: 0.7789 - val_loss: 0.5290 - val_acc: 0.7771
# Epoch 50/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5142 - acc: 0.7792 - val_loss: 0.5211 - val_acc: 0.7788
# Epoch 51/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5132 - acc: 0.7787 - val_loss: 0.5310 - val_acc: 0.7771
# Epoch 52/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5137 - acc: 0.7787 - val_loss: 0.5208 - val_acc: 0.7775
# Epoch 53/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5138 - acc: 0.7790 - val_loss: 0.5334 - val_acc: 0.7786
# Epoch 54/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5135 - acc: 0.7782 - val_loss: 0.5346 - val_acc: 0.7792
# Epoch 55/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7798 - val_loss: 0.5251 - val_acc: 0.7784
# Epoch 56/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5144 - acc: 0.7805 - val_loss: 0.5261 - val_acc: 0.7775
# Epoch 57/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5151 - acc: 0.7805 - val_loss: 0.5299 - val_acc: 0.7731
# Epoch 58/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5125 - acc: 0.7791 - val_loss: 0.5271 - val_acc: 0.7775
# Epoch 59/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5134 - acc: 0.7795 - val_loss: 0.5325 - val_acc: 0.7782
# Epoch 60/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5134 - acc: 0.7790 - val_loss: 0.5343 - val_acc: 0.7786
# Epoch 61/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5126 - acc: 0.7808 - val_loss: 0.5319 - val_acc: 0.7782
# Epoch 62/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5141 - acc: 0.7777 - val_loss: 0.5224 - val_acc: 0.7777
# Epoch 63/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7795 - val_loss: 0.5222 - val_acc: 0.7782
# Epoch 64/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5155 - acc: 0.7798 - val_loss: 0.5262 - val_acc: 0.7788
# Epoch 65/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5140 - acc: 0.7792 - val_loss: 0.5297 - val_acc: 0.7752
# Epoch 66/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5114 - acc: 0.7784 - val_loss: 0.5238 - val_acc: 0.7773
# Epoch 67/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5153 - acc: 0.7784 - val_loss: 0.5295 - val_acc: 0.7765
# Epoch 68/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7801 - val_loss: 0.5375 - val_acc: 0.7765
# Epoch 69/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5120 - acc: 0.7805 - val_loss: 0.5355 - val_acc: 0.7729
# Epoch 70/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5137 - acc: 0.7798 - val_loss: 0.5371 - val_acc: 0.7771
# Epoch 71/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5130 - acc: 0.7794 - val_loss: 0.5296 - val_acc: 0.7782
# Epoch 72/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5133 - acc: 0.7797 - val_loss: 0.5276 - val_acc: 0.7782
# Epoch 73/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5134 - acc: 0.7786 - val_loss: 0.5367 - val_acc: 0.7769
# Epoch 74/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5118 - acc: 0.7794 - val_loss: 0.5309 - val_acc: 0.7784
# Epoch 75/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5147 - acc: 0.7783 - val_loss: 0.5310 - val_acc: 0.7765
# Epoch 76/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5144 - acc: 0.7802 - val_loss: 0.5265 - val_acc: 0.7742
# Epoch 77/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5119 - acc: 0.7799 - val_loss: 0.5288 - val_acc: 0.7769
# Epoch 78/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5112 - acc: 0.7808 - val_loss: 0.5430 - val_acc: 0.7773
# Epoch 79/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5116 - acc: 0.7790 - val_loss: 0.5412 - val_acc: 0.7761
# Epoch 80/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5135 - acc: 0.7794 - val_loss: 0.5295 - val_acc: 0.7777
# Epoch 81/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7792 - val_loss: 0.5327 - val_acc: 0.7763
# Epoch 82/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5140 - acc: 0.7788 - val_loss: 0.5266 - val_acc: 0.7775
# Epoch 83/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5128 - acc: 0.7811 - val_loss: 0.5342 - val_acc: 0.7758
# Epoch 84/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5139 - acc: 0.7778 - val_loss: 0.5277 - val_acc: 0.7775
# Epoch 85/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7781 - val_loss: 0.5283 - val_acc: 0.7779
# Epoch 86/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5116 - acc: 0.7797 - val_loss: 0.5372 - val_acc: 0.7758
# Epoch 87/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7798 - val_loss: 0.5328 - val_acc: 0.7756
# Epoch 88/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5123 - acc: 0.7794 - val_loss: 0.5372 - val_acc: 0.7752
# Epoch 89/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5116 - acc: 0.7786 - val_loss: 0.5342 - val_acc: 0.7773
# Epoch 90/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5115 - acc: 0.7805 - val_loss: 0.5310 - val_acc: 0.7777
# Epoch 91/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5140 - acc: 0.7790 - val_loss: 0.5297 - val_acc: 0.7756
# Epoch 92/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5133 - acc: 0.7802 - val_loss: 0.5269 - val_acc: 0.7714
# Epoch 93/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5136 - acc: 0.7800 - val_loss: 0.5308 - val_acc: 0.7784
# Epoch 94/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5117 - acc: 0.7804 - val_loss: 0.5322 - val_acc: 0.7777
# Epoch 95/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5143 - acc: 0.7800 - val_loss: 0.5281 - val_acc: 0.7767
# Epoch 96/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5127 - acc: 0.7809 - val_loss: 0.5374 - val_acc: 0.7773
# Epoch 97/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5134 - acc: 0.7790 - val_loss: 0.5287 - val_acc: 0.7754
# Epoch 98/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5147 - acc: 0.7799 - val_loss: 0.5466 - val_acc: 0.7746
# Epoch 99/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5174 - acc: 0.7782 - val_loss: 0.5309 - val_acc: 0.7803
# Epoch 100/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5119 - acc: 0.7789 - val_loss: 0.5420 - val_acc: 0.7714
# Epoch 101/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7791 - val_loss: 0.5333 - val_acc: 0.7782
# Epoch 102/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5126 - acc: 0.7795 - val_loss: 0.5321 - val_acc: 0.7763
# Epoch 103/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5140 - acc: 0.7791 - val_loss: 0.5261 - val_acc: 0.7782
# Epoch 104/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5130 - acc: 0.7792 - val_loss: 0.5353 - val_acc: 0.7761
# Epoch 105/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5129 - acc: 0.7772 - val_loss: 0.5362 - val_acc: 0.7773
# Epoch 106/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5126 - acc: 0.7814 - val_loss: 0.5346 - val_acc: 0.7773
# Epoch 107/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5121 - acc: 0.7806 - val_loss: 0.5319 - val_acc: 0.7763
# Epoch 108/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7781 - val_loss: 0.5390 - val_acc: 0.7792
# Epoch 109/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5129 - acc: 0.7807 - val_loss: 0.5376 - val_acc: 0.7807
# Epoch 110/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5142 - acc: 0.7791 - val_loss: 0.5302 - val_acc: 0.7786
# Epoch 111/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5113 - acc: 0.7795 - val_loss: 0.5337 - val_acc: 0.7784
# Epoch 112/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5128 - acc: 0.7814 - val_loss: 0.5406 - val_acc: 0.7752
# Epoch 113/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5133 - acc: 0.7811 - val_loss: 0.5333 - val_acc: 0.7763
# Epoch 114/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5115 - acc: 0.7805 - val_loss: 0.5409 - val_acc: 0.7792
# Epoch 115/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5139 - acc: 0.7803 - val_loss: 0.5393 - val_acc: 0.7767
# Epoch 116/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5129 - acc: 0.7785 - val_loss: 0.5323 - val_acc: 0.7758
# Epoch 117/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5125 - acc: 0.7791 - val_loss: 0.5340 - val_acc: 0.7775
# Epoch 118/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5125 - acc: 0.7785 - val_loss: 0.5335 - val_acc: 0.7784
# Epoch 119/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7785 - val_loss: 0.5275 - val_acc: 0.7752
# Epoch 120/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5138 - acc: 0.7808 - val_loss: 0.5283 - val_acc: 0.7752
# Epoch 121/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5137 - acc: 0.7783 - val_loss: 0.5287 - val_acc: 0.7803
# Epoch 122/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5137 - acc: 0.7813 - val_loss: 0.5343 - val_acc: 0.7763
# Epoch 123/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5120 - acc: 0.7791 - val_loss: 0.5472 - val_acc: 0.7754
# Epoch 124/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7815 - val_loss: 0.5339 - val_acc: 0.7752
# Epoch 125/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5123 - acc: 0.7791 - val_loss: 0.5317 - val_acc: 0.7786
# Epoch 126/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7795 - val_loss: 0.5396 - val_acc: 0.7750
# Epoch 127/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5129 - acc: 0.7794 - val_loss: 0.5362 - val_acc: 0.7758
# Epoch 128/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5141 - acc: 0.7784 - val_loss: 0.5280 - val_acc: 0.7773
# Epoch 129/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5144 - acc: 0.7793 - val_loss: 0.5370 - val_acc: 0.7765
# Epoch 130/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5133 - acc: 0.7798 - val_loss: 0.5329 - val_acc: 0.7779
# Epoch 131/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5127 - acc: 0.7795 - val_loss: 0.5384 - val_acc: 0.7779
# Epoch 132/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5133 - acc: 0.7793 - val_loss: 0.5331 - val_acc: 0.7786
# Epoch 133/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5133 - acc: 0.7795 - val_loss: 0.5417 - val_acc: 0.7756
# Epoch 134/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5133 - acc: 0.7804 - val_loss: 0.5416 - val_acc: 0.7761
# Epoch 135/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5122 - acc: 0.7798 - val_loss: 0.5494 - val_acc: 0.7786
# Epoch 136/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5111 - acc: 0.7803 - val_loss: 0.5394 - val_acc: 0.7763
# Epoch 137/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5131 - acc: 0.7802 - val_loss: 0.5527 - val_acc: 0.7765
# Epoch 138/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7788 - val_loss: 0.5372 - val_acc: 0.7786
# Epoch 139/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5138 - acc: 0.7800 - val_loss: 0.5364 - val_acc: 0.7773
# Epoch 140/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5121 - acc: 0.7791 - val_loss: 0.5358 - val_acc: 0.7777
# Epoch 141/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7813 - val_loss: 0.5381 - val_acc: 0.7771
# Epoch 142/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5124 - acc: 0.7823 - val_loss: 0.5524 - val_acc: 0.7758
# Epoch 143/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5150 - acc: 0.7796 - val_loss: 0.5401 - val_acc: 0.7761
# Epoch 144/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5156 - acc: 0.7794 - val_loss: 0.5382 - val_acc: 0.7786
# Epoch 145/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5129 - acc: 0.7803 - val_loss: 0.5351 - val_acc: 0.7788
# Epoch 146/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5162 - acc: 0.7795 - val_loss: 0.5423 - val_acc: 0.7786
# Epoch 147/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5147 - acc: 0.7809 - val_loss: 0.5476 - val_acc: 0.7788
# Epoch 148/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5181 - acc: 0.7785 - val_loss: 0.5390 - val_acc: 0.7748
# Epoch 149/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5160 - acc: 0.7792 - val_loss: 0.5350 - val_acc: 0.7754
# Epoch 150/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5144 - acc: 0.7808 - val_loss: 0.5435 - val_acc: 0.7761
# Epoch 151/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5131 - acc: 0.7810 - val_loss: 0.5453 - val_acc: 0.7748
# Epoch 152/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7781 - val_loss: 0.5485 - val_acc: 0.7782
# Epoch 153/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5124 - acc: 0.7797 - val_loss: 0.5430 - val_acc: 0.7761
# Epoch 154/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5132 - acc: 0.7788 - val_loss: 0.5342 - val_acc: 0.7777
# Epoch 155/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5167 - acc: 0.7784 - val_loss: 0.5403 - val_acc: 0.7748
# Epoch 156/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5159 - acc: 0.7779 - val_loss: 0.5348 - val_acc: 0.7779
# Epoch 157/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5138 - acc: 0.7778 - val_loss: 0.5332 - val_acc: 0.7767
# Epoch 158/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5164 - acc: 0.7784 - val_loss: 0.5418 - val_acc: 0.7782
# Epoch 159/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5157 - acc: 0.7788 - val_loss: 0.5392 - val_acc: 0.7792
# Epoch 160/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5182 - acc: 0.7777 - val_loss: 0.5328 - val_acc: 0.7771
# Epoch 161/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5123 - acc: 0.7795 - val_loss: 0.5370 - val_acc: 0.7775
# Epoch 162/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7792 - val_loss: 0.5365 - val_acc: 0.7775
# Epoch 163/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5138 - acc: 0.7772 - val_loss: 0.5512 - val_acc: 0.7775
# Epoch 164/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7796 - val_loss: 0.5464 - val_acc: 0.7761
# Epoch 165/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5156 - acc: 0.7802 - val_loss: 0.5319 - val_acc: 0.7765
# Epoch 166/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7792 - val_loss: 0.5352 - val_acc: 0.7777
# Epoch 167/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7804 - val_loss: 0.5367 - val_acc: 0.7727
# Epoch 168/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5128 - acc: 0.7790 - val_loss: 0.5497 - val_acc: 0.7782
# Epoch 169/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5160 - acc: 0.7802 - val_loss: 0.5376 - val_acc: 0.7777
# Epoch 170/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5163 - acc: 0.7780 - val_loss: 0.5382 - val_acc: 0.7752
# Epoch 171/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5135 - acc: 0.7799 - val_loss: 0.5344 - val_acc: 0.7779
# Epoch 172/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7792 - val_loss: 0.5385 - val_acc: 0.7765
# Epoch 173/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5163 - acc: 0.7786 - val_loss: 0.5323 - val_acc: 0.7769
# Epoch 174/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5151 - acc: 0.7788 - val_loss: 0.5377 - val_acc: 0.7754
# Epoch 175/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7795 - val_loss: 0.5474 - val_acc: 0.7744
# Epoch 176/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5152 - acc: 0.7798 - val_loss: 0.5349 - val_acc: 0.7754
# Epoch 177/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5130 - acc: 0.7818 - val_loss: 0.5381 - val_acc: 0.7700
# Epoch 178/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7804 - val_loss: 0.5394 - val_acc: 0.7727
# Epoch 179/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5166 - acc: 0.7771 - val_loss: 0.5375 - val_acc: 0.7763
# Epoch 180/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5135 - acc: 0.7803 - val_loss: 0.5408 - val_acc: 0.7752
# Epoch 181/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5146 - acc: 0.7792 - val_loss: 0.5377 - val_acc: 0.7794
# Epoch 182/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5157 - acc: 0.7791 - val_loss: 0.5306 - val_acc: 0.7782
# Epoch 183/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5132 - acc: 0.7804 - val_loss: 0.5412 - val_acc: 0.7706
# Epoch 184/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5199 - acc: 0.7790 - val_loss: 0.5338 - val_acc: 0.7771
# Epoch 185/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5179 - acc: 0.7794 - val_loss: 0.5358 - val_acc: 0.7769
# Epoch 186/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7795 - val_loss: 0.5417 - val_acc: 0.7790
# Epoch 187/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5133 - acc: 0.7783 - val_loss: 0.5421 - val_acc: 0.7748
# Epoch 188/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5139 - acc: 0.7777 - val_loss: 0.5369 - val_acc: 0.7761
# Epoch 189/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5156 - acc: 0.7790 - val_loss: 0.5419 - val_acc: 0.7716
# Epoch 190/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7785 - val_loss: 0.5414 - val_acc: 0.7723
# Epoch 191/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5122 - acc: 0.7795 - val_loss: 0.5314 - val_acc: 0.7788
# Epoch 192/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5135 - acc: 0.7782 - val_loss: 0.5365 - val_acc: 0.7771
# Epoch 193/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7783 - val_loss: 0.5394 - val_acc: 0.7750
# Epoch 194/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5169 - acc: 0.7767 - val_loss: 0.5420 - val_acc: 0.7775
# Epoch 195/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5200 - acc: 0.7777 - val_loss: 0.5368 - val_acc: 0.7750
# Epoch 196/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5156 - acc: 0.7785 - val_loss: 0.5312 - val_acc: 0.7775
# Epoch 197/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5167 - acc: 0.7791 - val_loss: 0.5480 - val_acc: 0.7693
# Epoch 198/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5155 - acc: 0.7778 - val_loss: 0.5388 - val_acc: 0.7756
# Epoch 199/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5178 - acc: 0.7770 - val_loss: 0.5358 - val_acc: 0.7773
# Epoch 200/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5180 - acc: 0.7782 - val_loss: 0.5358 - val_acc: 0.7777
# Epoch 201/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5169 - acc: 0.7806 - val_loss: 0.5342 - val_acc: 0.7731
# Epoch 202/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5163 - acc: 0.7768 - val_loss: 0.5314 - val_acc: 0.7769
# Epoch 203/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7798 - val_loss: 0.5457 - val_acc: 0.7744
# Epoch 204/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5174 - acc: 0.7794 - val_loss: 0.5375 - val_acc: 0.7771
# Epoch 205/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7802 - val_loss: 0.5295 - val_acc: 0.7771
# Epoch 206/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5144 - acc: 0.7805 - val_loss: 0.5396 - val_acc: 0.7771
# Epoch 207/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5173 - acc: 0.7792 - val_loss: 0.5361 - val_acc: 0.7765
# Epoch 208/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5141 - acc: 0.7805 - val_loss: 0.5341 - val_acc: 0.7782
# Epoch 209/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5165 - acc: 0.7797 - val_loss: 0.5286 - val_acc: 0.7754
# Epoch 210/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5152 - acc: 0.7783 - val_loss: 0.5378 - val_acc: 0.7754
# Epoch 211/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5216 - acc: 0.7785 - val_loss: 0.5300 - val_acc: 0.7765
# Epoch 212/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5159 - acc: 0.7798 - val_loss: 0.5419 - val_acc: 0.7737
# Epoch 213/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5184 - acc: 0.7781 - val_loss: 0.5321 - val_acc: 0.7735
# Epoch 214/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5158 - acc: 0.7805 - val_loss: 0.5289 - val_acc: 0.7761
# Epoch 215/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5146 - acc: 0.7805 - val_loss: 0.5357 - val_acc: 0.7773
# Epoch 216/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5176 - acc: 0.7777 - val_loss: 0.5414 - val_acc: 0.7782
# Epoch 217/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7781 - val_loss: 0.5421 - val_acc: 0.7763
# Epoch 218/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5143 - acc: 0.7789 - val_loss: 0.5508 - val_acc: 0.7767
# Epoch 219/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5188 - acc: 0.7789 - val_loss: 0.5371 - val_acc: 0.7758
# Epoch 220/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5168 - acc: 0.7814 - val_loss: 0.5368 - val_acc: 0.7750
# Epoch 221/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5159 - acc: 0.7783 - val_loss: 0.5394 - val_acc: 0.7716
# Epoch 222/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7790 - val_loss: 0.5326 - val_acc: 0.7763
# Epoch 223/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7787 - val_loss: 0.5347 - val_acc: 0.7788
# Epoch 224/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5145 - acc: 0.7780 - val_loss: 0.5331 - val_acc: 0.7771
# Epoch 225/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5152 - acc: 0.7788 - val_loss: 0.5454 - val_acc: 0.7750
# Epoch 226/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5206 - acc: 0.7783 - val_loss: 0.5376 - val_acc: 0.7758
# Epoch 227/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5174 - acc: 0.7799 - val_loss: 0.5542 - val_acc: 0.7775
# Epoch 228/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5165 - acc: 0.7785 - val_loss: 0.5444 - val_acc: 0.7758
# Epoch 229/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5168 - acc: 0.7789 - val_loss: 0.5482 - val_acc: 0.7733
# Epoch 230/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7792 - val_loss: 0.5410 - val_acc: 0.7693
# Epoch 231/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5173 - acc: 0.7784 - val_loss: 0.5401 - val_acc: 0.7765
# Epoch 232/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5160 - acc: 0.7799 - val_loss: 0.5430 - val_acc: 0.7752
# Epoch 233/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5163 - acc: 0.7781 - val_loss: 0.5385 - val_acc: 0.7782
# Epoch 234/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5199 - acc: 0.7791 - val_loss: 0.5370 - val_acc: 0.7748
# Epoch 235/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5146 - acc: 0.7797 - val_loss: 0.5448 - val_acc: 0.7779
# Epoch 236/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5171 - acc: 0.7776 - val_loss: 0.5602 - val_acc: 0.7727
# Epoch 237/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5147 - acc: 0.7779 - val_loss: 0.5479 - val_acc: 0.7777
# Epoch 238/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5155 - acc: 0.7783 - val_loss: 0.5417 - val_acc: 0.7763
# Epoch 239/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5165 - acc: 0.7795 - val_loss: 0.5356 - val_acc: 0.7752
# Epoch 240/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5142 - acc: 0.7792 - val_loss: 0.5478 - val_acc: 0.7742
# Epoch 241/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5235 - acc: 0.7800 - val_loss: 0.5457 - val_acc: 0.7731
# Epoch 242/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7796 - val_loss: 0.5461 - val_acc: 0.7763
# Epoch 243/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7784 - val_loss: 0.5385 - val_acc: 0.7773
# Epoch 244/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5165 - acc: 0.7787 - val_loss: 0.5458 - val_acc: 0.7752
# Epoch 245/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5120 - acc: 0.7793 - val_loss: 0.5389 - val_acc: 0.7765
# Epoch 246/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5172 - acc: 0.7787 - val_loss: 0.5462 - val_acc: 0.7767
# Epoch 247/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5182 - acc: 0.7788 - val_loss: 0.5428 - val_acc: 0.7748
# Epoch 248/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5159 - acc: 0.7783 - val_loss: 0.5513 - val_acc: 0.7748
# Epoch 249/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5182 - acc: 0.7780 - val_loss: 0.5501 - val_acc: 0.7790
# Epoch 250/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5136 - acc: 0.7799 - val_loss: 0.5398 - val_acc: 0.7756
# Epoch 251/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7791 - val_loss: 0.5415 - val_acc: 0.7748
# Epoch 252/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7786 - val_loss: 0.5567 - val_acc: 0.7748
# Epoch 253/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5181 - acc: 0.7793 - val_loss: 0.5293 - val_acc: 0.7765
# Epoch 254/500
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5225 - acc: 0.7779 - val_loss: 0.5368 - val_acc: 0.7739
# Epoch 255/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5147 - acc: 0.7784 - val_loss: 0.5381 - val_acc: 0.7761
# Epoch 256/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5157 - acc: 0.7805 - val_loss: 0.5493 - val_acc: 0.7758
# Epoch 257/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5214 - acc: 0.7802 - val_loss: 0.5370 - val_acc: 0.7767
# Epoch 258/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5175 - acc: 0.7785 - val_loss: 0.5583 - val_acc: 0.7744
# Epoch 259/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5207 - acc: 0.7797 - val_loss: 0.5568 - val_acc: 0.7739
# Epoch 260/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5166 - acc: 0.7776 - val_loss: 0.5506 - val_acc: 0.7739
# Epoch 261/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5139 - acc: 0.7804 - val_loss: 0.5446 - val_acc: 0.7739
# Epoch 262/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5180 - acc: 0.7791 - val_loss: 0.5411 - val_acc: 0.7737
# Epoch 263/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5169 - acc: 0.7782 - val_loss: 0.5373 - val_acc: 0.7756
# Epoch 264/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5172 - acc: 0.7800 - val_loss: 0.5434 - val_acc: 0.7758
# Epoch 265/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5151 - acc: 0.7800 - val_loss: 0.5329 - val_acc: 0.7758
# Epoch 266/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5160 - acc: 0.7804 - val_loss: 0.5412 - val_acc: 0.7765
# Epoch 267/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5156 - acc: 0.7793 - val_loss: 0.5445 - val_acc: 0.7765
# Epoch 268/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5179 - acc: 0.7795 - val_loss: 0.5400 - val_acc: 0.7803
# Epoch 269/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5150 - acc: 0.7791 - val_loss: 0.5619 - val_acc: 0.7712
# Epoch 270/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5184 - acc: 0.7794 - val_loss: 0.5386 - val_acc: 0.7756
# Epoch 271/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5171 - acc: 0.7795 - val_loss: 0.5420 - val_acc: 0.7731
# Epoch 272/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5196 - acc: 0.7801 - val_loss: 0.5550 - val_acc: 0.7771
# Epoch 273/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5169 - acc: 0.7795 - val_loss: 0.5445 - val_acc: 0.7773
# Epoch 274/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5174 - acc: 0.7792 - val_loss: 0.5554 - val_acc: 0.7782
# Epoch 275/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5188 - acc: 0.7788 - val_loss: 0.5517 - val_acc: 0.7718
# Epoch 276/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5172 - acc: 0.7794 - val_loss: 0.5456 - val_acc: 0.7744
# Epoch 277/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5140 - acc: 0.7789 - val_loss: 0.5494 - val_acc: 0.7744
# Epoch 278/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5134 - acc: 0.7793 - val_loss: 0.5508 - val_acc: 0.7752
# Epoch 279/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7790 - val_loss: 0.5466 - val_acc: 0.7752
# Epoch 280/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5195 - acc: 0.7797 - val_loss: 0.5577 - val_acc: 0.7695
# Epoch 281/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5177 - acc: 0.7789 - val_loss: 0.5507 - val_acc: 0.7718
# Epoch 282/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5162 - acc: 0.7787 - val_loss: 0.5467 - val_acc: 0.7765
# Epoch 283/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5223 - acc: 0.7801 - val_loss: 0.5419 - val_acc: 0.7763
# Epoch 284/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5205 - acc: 0.7794 - val_loss: 0.5493 - val_acc: 0.7739
# Epoch 285/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5164 - acc: 0.7797 - val_loss: 0.5513 - val_acc: 0.7773
# Epoch 286/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5204 - acc: 0.7782 - val_loss: 0.5440 - val_acc: 0.7729
# Epoch 287/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5176 - acc: 0.7793 - val_loss: 0.5457 - val_acc: 0.7777
# Epoch 288/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5193 - acc: 0.7795 - val_loss: 0.5536 - val_acc: 0.7742
# Epoch 289/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5162 - acc: 0.7789 - val_loss: 0.5475 - val_acc: 0.7771
# Epoch 290/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5203 - acc: 0.7789 - val_loss: 0.5519 - val_acc: 0.7744
# Epoch 291/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5181 - acc: 0.7793 - val_loss: 0.5534 - val_acc: 0.7765
# Epoch 292/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5186 - acc: 0.7787 - val_loss: 0.5402 - val_acc: 0.7735
# Epoch 293/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5194 - acc: 0.7780 - val_loss: 0.5404 - val_acc: 0.7731
# Epoch 294/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5148 - acc: 0.7805 - val_loss: 0.5434 - val_acc: 0.7761
# Epoch 295/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5227 - acc: 0.7780 - val_loss: 0.5547 - val_acc: 0.7761
# Epoch 296/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5231 - acc: 0.7783 - val_loss: 0.5523 - val_acc: 0.7752
# Epoch 297/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5173 - acc: 0.7781 - val_loss: 0.5461 - val_acc: 0.7758
# Epoch 298/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5173 - acc: 0.7811 - val_loss: 0.5483 - val_acc: 0.7798
# Epoch 299/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5201 - acc: 0.7784 - val_loss: 0.5464 - val_acc: 0.7775
# Epoch 300/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5191 - acc: 0.7789 - val_loss: 0.5398 - val_acc: 0.7765
# Epoch 301/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5188 - acc: 0.7772 - val_loss: 0.5437 - val_acc: 0.7775
# Epoch 302/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5155 - acc: 0.7782 - val_loss: 0.5550 - val_acc: 0.7742
# Epoch 303/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5190 - acc: 0.7770 - val_loss: 0.5404 - val_acc: 0.7767
# Epoch 304/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5190 - acc: 0.7777 - val_loss: 0.5538 - val_acc: 0.7767
# Epoch 305/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5172 - acc: 0.7794 - val_loss: 0.5600 - val_acc: 0.7767
# Epoch 306/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5194 - acc: 0.7782 - val_loss: 0.5431 - val_acc: 0.7758
# Epoch 307/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5205 - acc: 0.7763 - val_loss: 0.5541 - val_acc: 0.7775
# Epoch 308/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5179 - acc: 0.7783 - val_loss: 0.5606 - val_acc: 0.7721
# Epoch 309/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5209 - acc: 0.7781 - val_loss: 0.5530 - val_acc: 0.7721
# Epoch 310/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5175 - acc: 0.7791 - val_loss: 0.5598 - val_acc: 0.7750
# Epoch 311/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5184 - acc: 0.7788 - val_loss: 0.5505 - val_acc: 0.7756
# Epoch 312/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5246 - acc: 0.7782 - val_loss: 0.5564 - val_acc: 0.7748
# Epoch 313/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5213 - acc: 0.7804 - val_loss: 0.5536 - val_acc: 0.7725
# Epoch 314/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5163 - acc: 0.7776 - val_loss: 0.5530 - val_acc: 0.7737
# Epoch 315/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5203 - acc: 0.7796 - val_loss: 0.5451 - val_acc: 0.7742
# Epoch 316/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5198 - acc: 0.7799 - val_loss: 0.5409 - val_acc: 0.7761
# Epoch 317/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5175 - acc: 0.7804 - val_loss: 0.5386 - val_acc: 0.7767
# Epoch 318/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5172 - acc: 0.7769 - val_loss: 0.5541 - val_acc: 0.7716
# Epoch 319/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5154 - acc: 0.7782 - val_loss: 0.5742 - val_acc: 0.7763
# Epoch 320/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5194 - acc: 0.7785 - val_loss: 0.5485 - val_acc: 0.7775
# Epoch 321/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5204 - acc: 0.7781 - val_loss: 0.5450 - val_acc: 0.7718
# Epoch 322/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5180 - acc: 0.7791 - val_loss: 0.5490 - val_acc: 0.7775
# Epoch 323/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5206 - acc: 0.7772 - val_loss: 0.5620 - val_acc: 0.7767
# Epoch 324/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5214 - acc: 0.7784 - val_loss: 0.5596 - val_acc: 0.7744
# Epoch 325/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5210 - acc: 0.7785 - val_loss: 0.5619 - val_acc: 0.7752
# Epoch 326/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5176 - acc: 0.7782 - val_loss: 0.5624 - val_acc: 0.7712
# Epoch 327/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5198 - acc: 0.7766 - val_loss: 0.5638 - val_acc: 0.7750
# Epoch 328/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5198 - acc: 0.7772 - val_loss: 0.5457 - val_acc: 0.7763
# Epoch 329/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5183 - acc: 0.7773 - val_loss: 0.5621 - val_acc: 0.7763
# Epoch 330/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5236 - acc: 0.7764 - val_loss: 0.5455 - val_acc: 0.7754
# Epoch 331/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5153 - acc: 0.7783 - val_loss: 0.5585 - val_acc: 0.7765
# Epoch 332/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7795 - val_loss: 0.5572 - val_acc: 0.7718
# Epoch 333/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5192 - acc: 0.7809 - val_loss: 0.5518 - val_acc: 0.7739
# Epoch 334/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5175 - acc: 0.7784 - val_loss: 0.5566 - val_acc: 0.7775
# Epoch 335/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5180 - acc: 0.7789 - val_loss: 0.5564 - val_acc: 0.7756
# Epoch 336/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5250 - acc: 0.7786 - val_loss: 0.5558 - val_acc: 0.7777
# Epoch 337/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7807 - val_loss: 0.5465 - val_acc: 0.7763
# Epoch 338/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5214 - acc: 0.7771 - val_loss: 0.5459 - val_acc: 0.7771
# Epoch 339/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5186 - acc: 0.7789 - val_loss: 0.5589 - val_acc: 0.7767
# Epoch 340/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5244 - acc: 0.7778 - val_loss: 0.5649 - val_acc: 0.7763
# Epoch 341/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5192 - acc: 0.7779 - val_loss: 0.5502 - val_acc: 0.7769
# Epoch 342/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5191 - acc: 0.7795 - val_loss: 0.5508 - val_acc: 0.7756
# Epoch 343/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5200 - acc: 0.7793 - val_loss: 0.5687 - val_acc: 0.7761
# Epoch 344/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5221 - acc: 0.7788 - val_loss: 0.5444 - val_acc: 0.7765
# Epoch 345/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5173 - acc: 0.7768 - val_loss: 0.5567 - val_acc: 0.7756
# Epoch 346/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5199 - acc: 0.7789 - val_loss: 0.5510 - val_acc: 0.7754
# Epoch 347/500
# ...
# Epoch 383/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5258 - acc: 0.7790 - val_loss: 0.5476 - val_acc: 0.7786
# Epoch 384/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5246 - acc: 0.7792 - val_loss: 0.5509 - val_acc: 0.7752
# Epoch 385/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5239 - acc: 0.7781 - val_loss: 0.5476 - val_acc: 0.7761
# Epoch 386/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5211 - acc: 0.7780 - val_loss: 0.5453 - val_acc: 0.7725
# Epoch 387/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5348 - acc: 0.7776 - val_loss: 0.5396 - val_acc: 0.7735
# Epoch 388/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5198 - acc: 0.7792 - val_loss: 0.5482 - val_acc: 0.7733
# Epoch 389/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5193 - acc: 0.7779 - val_loss: 0.5524 - val_acc: 0.7735
# Epoch 390/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5190 - acc: 0.7784 - val_loss: 0.5446 - val_acc: 0.7739
# Epoch 391/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5227 - acc: 0.7779 - val_loss: 0.5426 - val_acc: 0.7773
# Epoch 392/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5171 - acc: 0.7793 - val_loss: 0.5488 - val_acc: 0.7777
# Epoch 393/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5248 - acc: 0.7792 - val_loss: 0.5469 - val_acc: 0.7737
# Epoch 394/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5223 - acc: 0.7790 - val_loss: 0.5464 - val_acc: 0.7723
# Epoch 395/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5246 - acc: 0.7791 - val_loss: 0.5525 - val_acc: 0.7725
# Epoch 396/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5191 - acc: 0.7784 - val_loss: 0.5497 - val_acc: 0.7746
# Epoch 397/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5199 - acc: 0.7803 - val_loss: 0.5418 - val_acc: 0.7773
# Epoch 398/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5262 - acc: 0.7808 - val_loss: 0.5510 - val_acc: 0.7763
# Epoch 399/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5226 - acc: 0.7782 - val_loss: 0.5371 - val_acc: 0.7744
# Epoch 400/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5196 - acc: 0.7777 - val_loss: 0.5476 - val_acc: 0.7796
# Epoch 401/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5222 - acc: 0.7778 - val_loss: 0.5474 - val_acc: 0.7784
# Epoch 402/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5242 - acc: 0.7794 - val_loss: 0.5600 - val_acc: 0.7752
# Epoch 403/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5253 - acc: 0.7777 - val_loss: 0.5496 - val_acc: 0.7777
# Epoch 404/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5192 - acc: 0.7791 - val_loss: 0.5768 - val_acc: 0.7733
# Epoch 405/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5203 - acc: 0.7783 - val_loss: 0.5612 - val_acc: 0.7756
# Epoch 406/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5214 - acc: 0.7759 - val_loss: 0.5544 - val_acc: 0.7769
# Epoch 407/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5226 - acc: 0.7778 - val_loss: 0.5587 - val_acc: 0.7786
# Epoch 408/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5178 - acc: 0.7791 - val_loss: 0.5499 - val_acc: 0.7746
# Epoch 409/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5287 - acc: 0.7784 - val_loss: 0.5485 - val_acc: 0.7777
# Epoch 410/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5223 - acc: 0.7779 - val_loss: 0.5541 - val_acc: 0.7788
# Epoch 411/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5199 - acc: 0.7779 - val_loss: 0.5583 - val_acc: 0.7767
# Epoch 412/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5231 - acc: 0.7780 - val_loss: 0.5395 - val_acc: 0.7752
# Epoch 413/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5192 - acc: 0.7786 - val_loss: 0.5516 - val_acc: 0.7746
# Epoch 414/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5202 - acc: 0.7780 - val_loss: 0.5459 - val_acc: 0.7765
# Epoch 415/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5213 - acc: 0.7779 - val_loss: 0.5430 - val_acc: 0.7784
# Epoch 416/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5191 - acc: 0.7792 - val_loss: 0.5462 - val_acc: 0.7775
# Epoch 417/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5196 - acc: 0.7782 - val_loss: 0.5387 - val_acc: 0.7754
# Epoch 418/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5221 - acc: 0.7783 - val_loss: 0.5440 - val_acc: 0.7763
# Epoch 419/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5199 - acc: 0.7778 - val_loss: 0.5429 - val_acc: 0.7765
# Epoch 420/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5218 - acc: 0.7776 - val_loss: 0.5459 - val_acc: 0.7775
# Epoch 421/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5208 - acc: 0.7779 - val_loss: 0.5509 - val_acc: 0.7712
# Epoch 422/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5221 - acc: 0.7776 - val_loss: 0.5570 - val_acc: 0.7782
# Epoch 423/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5184 - acc: 0.7802 - val_loss: 0.5621 - val_acc: 0.7746
# Epoch 424/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5267 - acc: 0.7792 - val_loss: 0.5561 - val_acc: 0.7773
# Epoch 425/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5267 - acc: 0.7780 - val_loss: 0.5472 - val_acc: 0.7769
# Epoch 426/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5298 - acc: 0.7773 - val_loss: 0.5470 - val_acc: 0.7756
# Epoch 427/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5197 - acc: 0.7772 - val_loss: 0.5462 - val_acc: 0.7777
# Epoch 428/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5227 - acc: 0.7799 - val_loss: 0.5487 - val_acc: 0.7733
# Epoch 429/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5259 - acc: 0.7781 - val_loss: 0.5381 - val_acc: 0.7752
# Epoch 430/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5284 - acc: 0.7777 - val_loss: 0.5468 - val_acc: 0.7739
# Epoch 431/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5238 - acc: 0.7758 - val_loss: 0.5423 - val_acc: 0.7754
# Epoch 432/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5216 - acc: 0.7774 - val_loss: 0.5366 - val_acc: 0.7758
# Epoch 433/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5299 - acc: 0.7754 - val_loss: 0.5332 - val_acc: 0.7758
# Epoch 434/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5183 - acc: 0.7792 - val_loss: 0.5494 - val_acc: 0.7761
# Epoch 435/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5226 - acc: 0.7791 - val_loss: 0.5428 - val_acc: 0.7721
# Epoch 436/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5195 - acc: 0.7802 - val_loss: 0.5533 - val_acc: 0.7779
# Epoch 437/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5173 - acc: 0.7785 - val_loss: 0.5545 - val_acc: 0.7771
# Epoch 438/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5189 - acc: 0.7779 - val_loss: 0.5490 - val_acc: 0.7763
# Epoch 439/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5269 - acc: 0.7768 - val_loss: 0.5419 - val_acc: 0.7771
# Epoch 440/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5208 - acc: 0.7785 - val_loss: 0.5366 - val_acc: 0.7748
# Epoch 441/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5229 - acc: 0.7781 - val_loss: 0.5717 - val_acc: 0.7742
# Epoch 442/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5257 - acc: 0.7774 - val_loss: 0.5503 - val_acc: 0.7748
# Epoch 443/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5227 - acc: 0.7795 - val_loss: 0.5606 - val_acc: 0.7668
# Epoch 444/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5236 - acc: 0.7787 - val_loss: 0.5617 - val_acc: 0.7769
# Epoch 445/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5202 - acc: 0.7786 - val_loss: 0.5378 - val_acc: 0.7744
# Epoch 446/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5206 - acc: 0.7771 - val_loss: 0.5572 - val_acc: 0.7700
# Epoch 447/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5234 - acc: 0.7785 - val_loss: 0.5573 - val_acc: 0.7752
# Epoch 448/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5273 - acc: 0.7792 - val_loss: 0.5647 - val_acc: 0.7735
# Epoch 449/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5214 - acc: 0.7768 - val_loss: 0.5434 - val_acc: 0.7782
# Epoch 450/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5257 - acc: 0.7793 - val_loss: 0.5535 - val_acc: 0.7763
# Epoch 451/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5227 - acc: 0.7781 - val_loss: 0.5660 - val_acc: 0.7750
# Epoch 452/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5238 - acc: 0.7780 - val_loss: 0.5501 - val_acc: 0.7771
# Epoch 453/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5238 - acc: 0.7772 - val_loss: 0.5442 - val_acc: 0.7750
# Epoch 454/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5286 - acc: 0.7789 - val_loss: 0.5458 - val_acc: 0.7771
# Epoch 455/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5212 - acc: 0.7767 - val_loss: 0.5505 - val_acc: 0.7706
# Epoch 456/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.5267 - acc: 0.7778 - val_loss: 0.5430 - val_acc: 0.7761
# Epoch 457/500
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5236 - acc: 0.7770 - val_loss: 0.5499 - val_acc: 0.7729
# Epoch 458/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5254 - acc: 0.7784 - val_loss: 0.5546 - val_acc: 0.7746
# Epoch 459/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5234 - acc: 0.7788 - val_loss: 0.5460 - val_acc: 0.7756
# Epoch 460/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5265 - acc: 0.7783 - val_loss: 0.5451 - val_acc: 0.7714
# Epoch 461/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5232 - acc: 0.7784 - val_loss: 0.5542 - val_acc: 0.7714
# Epoch 462/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5274 - acc: 0.7780 - val_loss: 0.5404 - val_acc: 0.7704
# Epoch 463/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5264 - acc: 0.7776 - val_loss: 0.5393 - val_acc: 0.7763
# Epoch 464/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5210 - acc: 0.7767 - val_loss: 0.5451 - val_acc: 0.7727
# Epoch 465/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5212 - acc: 0.7789 - val_loss: 0.5566 - val_acc: 0.7756
# Epoch 466/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5329 - acc: 0.7776 - val_loss: 0.5616 - val_acc: 0.7689
# Epoch 467/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5228 - acc: 0.7777 - val_loss: 0.5471 - val_acc: 0.7773
# Epoch 468/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5286 - acc: 0.7783 - val_loss: 0.5449 - val_acc: 0.7771
# Epoch 469/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5239 - acc: 0.7787 - val_loss: 0.5461 - val_acc: 0.7779
# Epoch 470/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5233 - acc: 0.7781 - val_loss: 0.5483 - val_acc: 0.7758
# Epoch 471/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5267 - acc: 0.7773 - val_loss: 0.5443 - val_acc: 0.7767
# Epoch 472/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5174 - acc: 0.7776 - val_loss: 0.5614 - val_acc: 0.7735
# Epoch 473/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5181 - acc: 0.7796 - val_loss: 0.5552 - val_acc: 0.7758
# Epoch 474/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5242 - acc: 0.7757 - val_loss: 0.5527 - val_acc: 0.7767
# Epoch 475/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5219 - acc: 0.7788 - val_loss: 0.5413 - val_acc: 0.7748
# Epoch 476/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5201 - acc: 0.7796 - val_loss: 0.5601 - val_acc: 0.7729
# Epoch 477/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5213 - acc: 0.7793 - val_loss: 0.5485 - val_acc: 0.7765
# Epoch 478/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5219 - acc: 0.7774 - val_loss: 0.5652 - val_acc: 0.7735
# Epoch 479/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5185 - acc: 0.7788 - val_loss: 0.5673 - val_acc: 0.7708
# Epoch 480/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5273 - acc: 0.7741 - val_loss: 0.5450 - val_acc: 0.7710
# Epoch 481/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5240 - acc: 0.7787 - val_loss: 0.5618 - val_acc: 0.7729
# Epoch 482/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5309 - acc: 0.7763 - val_loss: 0.5549 - val_acc: 0.7763
# Epoch 483/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5237 - acc: 0.7788 - val_loss: 0.5500 - val_acc: 0.7773
# Epoch 484/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5258 - acc: 0.7763 - val_loss: 0.5395 - val_acc: 0.7744
# Epoch 485/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5271 - acc: 0.7785 - val_loss: 0.5398 - val_acc: 0.7761
# Epoch 486/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5205 - acc: 0.7790 - val_loss: 0.5589 - val_acc: 0.7742
# Epoch 487/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5238 - acc: 0.7782 - val_loss: 0.5494 - val_acc: 0.7786
# Epoch 488/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5215 - acc: 0.7788 - val_loss: 0.5545 - val_acc: 0.7750
# Epoch 489/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5220 - acc: 0.7783 - val_loss: 0.5618 - val_acc: 0.7710
# Epoch 490/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5216 - acc: 0.7780 - val_loss: 0.5498 - val_acc: 0.7763
# Epoch 491/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5271 - acc: 0.7791 - val_loss: 0.5445 - val_acc: 0.7777
# Epoch 492/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.5312 - acc: 0.7785 - val_loss: 0.5470 - val_acc: 0.7754
# Epoch 493/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5248 - acc: 0.7782 - val_loss: 0.5492 - val_acc: 0.7775
# Epoch 494/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5183 - acc: 0.7792 - val_loss: 0.5537 - val_acc: 0.7718
# Epoch 495/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5270 - acc: 0.7777 - val_loss: 0.5433 - val_acc: 0.7761
# Epoch 496/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5270 - acc: 0.7792 - val_loss: 0.5496 - val_acc: 0.7761
# Epoch 497/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5225 - acc: 0.7770 - val_loss: 0.5491 - val_acc: 0.7748
# Epoch 498/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5230 - acc: 0.7766 - val_loss: 0.5412 - val_acc: 0.7744
# Epoch 499/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5215 - acc: 0.7776 - val_loss: 0.5417 - val_acc: 0.7763
# Epoch 500/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5250 - acc: 0.7764 - val_loss: 0.5592 - val_acc: 0.7714
#
# 	The model is trained

# %%
# @title First play a random player against itself and then the model against a random player.

x_strategy = random_player
o_strategy = random_player
games_rr = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(1000)]
game_stats(x_strategy, o_strategy, 100, games_rr)

x_strategy = model
o_strategy = random_player
games_mr = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(100)]
game_stats(x_strategy, o_strategy, 100, games_mr)

x_strategy = random_player
o_strategy = model
games_rm = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(100)]
game_stats(x_strategy, o_strategy, 100, games_rm)

x_strategy = model
o_strategy = model 
games_mm = [simulate_game(x_strategy=x_strategy, o_strategy=o_strategy) for _ in range(100)]
game_stats(x_strategy, o_strategy, 100, games_mm)
# Out:
# X (random_player) vs O (random_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 57	  57%
#    o	 29	  29%
#  Draws	 14	  14%
#
# X (model_player) vs O (random_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 51	  51%
#    o	 41	  41%
#  Draws	 8	  8%
#
# X (random_player) vs O (model_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 77	  77%
#    o	 14	  14%
#  Draws	 9	  9%
#
# X (model_player) vs O (model_player). 100 games.
# Player	wins	pct wins
# ------	----	--------
#    x	 100	  100%
#    o	 0	  0%
#  Draws	 0	  0%

# %% [markdown]
# * In the original the random player won 76% of games as x; the model won 98%
#
# * In the original the random player won 48% of games as o; the model won 96%.

# %%
x_strategy = human_player
o_strategy = model 
_ = simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, verbose=True)
# Out:
# Indicate a move as follows.
#
#    1     2    3
# A  A1 |  A2 | A3
#   ---------------
# B  B2 |  B2 | B3
#   ---------------
# C  C3 |  C2 | C3
#    Lower case a, b, c are also ok.
#
#
#
#
#     1   2   3
#  A    |   |
#    -----------
#  B    |   |
#    -----------
#  C    |   |
#
# X's move > a2
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# If  O  moves to (0, 0)
#     1   2   3
#  A  O | X |
#    -----------
#  B    |   |
#    -----------
#  C    |   |
# Draw = 0.39
# Draw = 0.38999998569488525
# X wins = 0.32
# X wins = 0.3199999928474426
# O wins = 0.29
# O wins = 0.28999999165534973
#
# If  O  moves to (0, 2)
#     1   2   3
#  A    | X | O
#    -----------
#  B    |   |
#    -----------
#  C    |   |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (1, 0)
#     1   2   3
#  A    | X |
#    -----------
#  B  O |   |
#    -----------
#  C    |   |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (1, 1)
#     1   2   3
#  A    | X |
#    -----------
#  B    | O |
#    -----------
#  C    |   |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (1, 2)
#     1   2   3
#  A    | X |
#    -----------
#  B    |   | O
#    -----------
#  C    |   |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (2, 0)
#     1   2   3
#  A    | X |
#    -----------
#  B    |   |
#    -----------
#  C  O |   |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (2, 1)
#     1   2   3
#  A    | X |
#    -----------
#  B    |   |
#    -----------
#  C    | O |
# Draw = 1.0
# Draw = 1.0
# X wins = 0.0
# X wins = 0.0
# O wins = 0.0
# O wins = 0.0
#
# If  O  moves to (2, 2)
#     1   2   3
#  A    | X |
#    -----------
#  B    |   |
#    -----------
#  C    |   | O
# Draw = 0.13
# Draw = 0.12999999523162842
# X wins = 0.03
# X wins = 0.029999999329447746
# O wins = 0.83
# O wins = 0.8299999833106995
#
# ==>  O  moves to (0, 0).
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
#
#     1   2   3
#  A  O | X |
#    -----------
#  B    |   |
#    -----------
#  C    |   |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-a1f649cd8e4e> in <module>
#       1 x_strategy = human_player
#       2 o_strategy = model
# ----> 3 _ = simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, verbose=True)
#
# <ipython-input-64-50eb75755003> in simulate_game(x_strategy, o_strategy, verbose, rnd)
#     179         player_to_move = obs.player_to_move
#     180         player_strategy = x_strategy if player_to_move == x else o_strategy
# --> 181         row, col = select_a_move(obs.board, player_to_move, player_strategy, config, verbose=verbose, rnd=rnd)
#     182         # Make the move
#     183         obs.board[row][col] = player_to_move
#
# <ipython-input-64-50eb75755003> in select_a_move(board, player, move_strategy, config, verbose, rnd)
#     150
#     151     if move_strategy == human_player:
# --> 152         return human_player(board, player, config)
#     153
#     154     return random_player(board, player, config)
#
# <ipython-input-64-50eb75755003> in human_player(board, player, config)
#      35     print()
#      36     print_board(board, config)
# ---> 37     r, c = get_input(board, config.player_symbol[player], config.blank)
#      38     return r, c
#      39
#
# <ipython-input-64-50eb75755003> in get_input(board, mark, blank)
#      17     valid_input = False
#      18     while not valid_input:
# ---> 19         strng = input(f'\n{mark[1]}\'s move > ')
#      20         digits = [c_to_n[c] for c in strng if c in c_to_n]
#      21
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# * We see that the game tends toward a draw, which is what we would expect from a couple of human players. Still, neither player is particularly good.

# %% [markdown]
# * As a final measure of skill, let's see how the length of the average game has changed. We would expect this to go down with an increased imbalance in skill levels.

# %%
# @title Compare the lengths of the games

def avg_game_length(games, prec=1):
    lengths_as_floats = [float(len(game)) for game in games]
    avg = np.mean(lengths_as_floats)
    return round(avg, prec)

print(f"Average length of fully random game is {avg_game_length(games)} moves")
print(f"Average length of game where x uses NN is {avg_game_length(games3)} moves")
print(f"Average length of game where o uses NN is {avg_game_length(games4)} moves")
print(f"Average length of game where both use NN is {avg_game_length(games5} moves")

# %% [markdown]
# * As shown above, the games are a move shorter for player 1 and a bit longer for player 2.

# %% [markdown]
# * Now, we play a game against our model and see how well it does. We let it make the first move.

# %%
# @title A human against the model

x_strategy = human_player
o_strategy = model
simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, rnd=0.6)
print()
# Out:
# Indicate a move as follows.
#
#    1     2    3
# A  A1 |  A2 | A3
#   ---------------
# B  B2 |  B2 | B3
#   ---------------
# C  C3 |  C2 | C3
#    Lower case a, b, c are also ok.
#
#
#
#
#     1   2   3
#  A    |   |
#    -----------
#  B    |   |
#    -----------
#  C    |   |
#
# X's move > a2
#
#
#
#     1   2   3
#  A    | X | O
#    -----------
#  B    |   |
#    -----------
#  C    |   |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-c10caad886c3> in <module>
#       3 x_strategy = human_player
#       4 o_strategy = model
# ----> 5 simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, rnd=0.6)
#       6 print()
#
# <ipython-input-64-50eb75755003> in simulate_game(x_strategy, o_strategy, verbose, rnd)
#     179         player_to_move = obs.player_to_move
#     180         player_strategy = x_strategy if player_to_move == x else o_strategy
# --> 181         row, col = select_a_move(obs.board, player_to_move, player_strategy, config, verbose=verbose, rnd=rnd)
#     182         # Make the move
#     183         obs.board[row][col] = player_to_move
#
# <ipython-input-64-50eb75755003> in select_a_move(board, player, move_strategy, config, verbose, rnd)
#     150
#     151     if move_strategy == human_player:
# --> 152         return human_player(board, player, config)
#     153
#     154     return random_player(board, player, config)
#
# <ipython-input-64-50eb75755003> in human_player(board, player, config)
#      35     print()
#      36     print_board(board, config)
# ---> 37     r, c = get_input(board, config.player_symbol[player], config.blank)
#      38     return r, c
#      39
#
# <ipython-input-64-50eb75755003> in get_input(board, mark, blank)
#      17     valid_input = False
#      18     while not valid_input:
# ---> 19         strng = input(f'\n{mark[1]}\'s move > ')
#      20         digits = [c_to_n[c] for c in strng if c in c_to_n]
#      21
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from numpy.core.memmap import ndarray
arr = np.full((1, ), 0.38999998569488525)
zp = zip(['a[0]'], arr)
for label, value in zp:
    print(label, '=', round(value, 2))
    print(f'{label} = {round(value, 2)}')
    # print(arr[0], np.around(arr[0], 1), round(arr[0], 1), f'{np.around(arr[0], 1)}', f'{round(arr[0], 1)}')
# Out:
# a[0] = 0.39
# a[0] = 0.39

# %%
# @title A human against the model

x_strategy = model
o_strategy = human_player 
simulate_game(x_strategy=x_strategy, o_strategy=o_strategy, rnd=0.6)
print()
